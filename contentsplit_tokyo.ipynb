# %%
#encoding=utf-8
import jieba
jieba.load_userdict("tokyo0123.txt")

# %%
content = open('jp03.csv',encoding="UTF-8").read()

# %%
import pandas as pd
df = pd.read_csv('jp03.csv')

# %%
tt=[]
with open('tokyo0123.txt',encoding="UTF-8") as f:
    for i in f:
      tt.append(i.strip())

# %%
A=set()
for partcontent in df['content']:
    words=jieba.cut(partcontent)
    for word in words:
        for ltt in tt:
            if word == ltt:
                A.add(ltt)
    if len(A)>1:
        print(A)
    A=set()
# Out:
# {'明治神宮', '井之頭公園', '三鷹之森吉卜力美術館', '上野', '東京', '銀座', '山手', '淺草寺', '原宿', '晴空塔'}
# {'明治神宮', '成田', '井之頭公園', '五重塔', '淺草', '東京', '雷門', '晴空塔', '築地市場', '淺草寺'}
# {'新宿', '富士山', '御殿場', '展望台'}
# {'群馬縣', '北陸', '上野', '東京', '八王子', '成田'}
# {'秋葉原', '六本木', '台場', '東京', '品川', '東京鐵塔', '品川水族館'}
# {'富士山', '台場', '淺草', '台場海濱公園', '東京', '新宿', '仲見世通', '雷門', '淺草寺', '淺草神社', '彩虹大橋'}
# {'八王子', '東京都', '甲府'}
# {'北陸', '東京灣', '箱根', '金澤', '東京', '群馬', '成田', '東京鐵塔'}
# {'築地', '東京都', '台場', '東京灣', '高德院', '東京', '銀座', '品川', '神奈川縣', '新宿', '鎌倉大佛', '展望台', '長谷', '成田', '江之島', '築地市場', '長谷寺'}
# {'六本木', '新大久保', '赤羽橋', '東京', '成田', '築地本願寺', '彩虹大橋', '富士山', '上野恩賜公園', '晴空塔', '築地市場', '秋葉原', '明治神宮', '靖國神社', '淺草花屋敷', '展望台', '原宿', '森美術館', '台場', '東京車站', '淺草', '銀座', '雷門', '東京鐵塔', '池袋'}
# {'六本木', '富士山', '明治神宮', '成田', '台場', '代代木公園', '上野', '淺草', '青山', '東京', '東京地鐵', '表參道', '青之洞窟', '新宿', '忠犬八公像', '展望台', '山手', '晴空塔', '原宿', '東京鐵塔'}
# {'上野', '雷門', '東京', '東京鐵塔', '淺草寺'}
# {'代官山', '富士山', '東京', '目黑川'}
# ...
