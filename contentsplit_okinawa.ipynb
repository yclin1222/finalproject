# %%
#encoding=utf-8
import jieba
jieba.load_userdict("okinawa_1.txt")

# %%
content = open('jp08.csv',encoding="UTF-8").read()

# %%
import pandas as pd
df = pd.read_csv('jp08.csv')

# %%
tt=[]
with open('okinawa_1.txt',encoding="UTF-8") as f:
    for i in f:
      tt.append(i.strip())

# %%
A=set()
for partcontent in df['content']:
    words=jieba.cut(partcontent)
    for word in words:
        for ltt in tt:
            if word == ltt:
                A.add(ltt)
    if len(A)>1:
        print(A)
    A=set()
# Out:
# {'名護市', '読谷村', '首里城', '國際通', '御菓子御殿', '沖繩', '中頭郡'}
# {'萬座毛', '波上宮', '古宇利島', '國際通', '波之上海灘', '那霸', '沖繩'}
# {'那霸機場', '沖繩'}
# {'國際通', '沖繩'}
# {'首里城', '金城町石疊道', '沖繩'}
# {'波上宮', '國際通', '沖繩'}
# {'首里城', '沖繩'}
# {'港川外人住宅', '沖繩', '浦添市'}
# {'港川外人住宅', '沖繩'}
# {'榮町市場', '沖繩'}
# {'榮町市場', '沖繩'}
# {'首里城', '國際通', '沖繩'}
# {'美麗海水族館', '沖繩'}
# {'沖繩', '國頭郡'}
# {'首里城', '沖繩'}
# {'古宇利大橋', '沖繩', '古宇利島'}
# {'座喜味城', '沖繩'}
# {'美國村', '沖繩'}
# {'那霸機場', '沖繩'}
# {'那霸市', '國際通', '沖繩', '那霸'}
# {'沖繩', '那霸'}
# {'波上宮', '國際通', '沖繩', '那霸'}
# {'萬座毛', '首里城', '金城町石疊道', '國場川', '那霸', '新都心', '沖繩'}
# {'勝連城跡', '美國村', '古宇利大橋', '國際通', '那霸', '海中道路', '沖繩', '普天間宮'}
# {'古宇利大橋', '名護市', '萬座毛', '古宇利島', '國際通', '那霸', '古宇利', '沖繩'}
# {'波上宮', '國際通', '沖繩', '浦添大公園'}
# {'豐見城市', '沖繩', '瀨長島'}
# {'奧武山公園', '波上宮', '國際通', '沖繩', '浦添大公園'}
# {'美國村', '古宇利大橋', '名護市', '西松屋', '浦添大公園', '沖繩'}
# {'首里城', '國際通', '沖繩', '那霸市'}
# {'那霸機場', '沖繩', '新都心', '國際通', '那霸'}
# {'美國村', '萬座毛', '永旺夢樂城沖繩來客夢', '那霸', '沖繩', '中頭郡'}
# {'那霸機場', '美國村', '名護市', '國際通', '那霸', '沖繩'}
# ...
